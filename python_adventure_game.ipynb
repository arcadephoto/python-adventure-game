# %%
import random

class Player():
    def __init__(self, name)
    self.name = name
    self.health = 10
    self.lives = 3
    self.items = []
    self.blanket_pieces = 0
    #must use player1 = ("name")


class Game():
    self.rooms = ["patrick says don't touch"]
    self.random = random
    
    def backstory(self):
        print("Billy writes this")
        

    def room_choice(self):
        #pop off chosen room
        i = random.randint(1, 6)
        if i == 1:
            hippos()
        if i == 2:
            clue()
        if i == 3:
            chutes()
        if i == 4:
            simon()
        if i == 5:
            connect_four()
            
        print("Player picks up the eight ball, shakes it, random choice to determine first room")

    def enter_room(self):
        #pop off previous room as having been visited
        print("Exit message. Player is transported to the first of five rooms.")
        
        
    def ending_story(self):
        #triggers if the player has all five shards
        
input("Player Name")
print("This is the backstory")
#Player walks down the hallway and has the first choice - which door to take
#At the end of the hallway, sitting on a pedestal, is a magic 8 ball.
#The player shakes it, and a random number generator gives a message and determines
#which is the first room


#At the "end" of each room, once the puzzle is solved, is a chest. The chest opens
# to reveal the toy, which randomly determines the next room.

#kid's name: Alexander III, Robert Winchester Jr. II, III., Vanessa IV

#five shards of a blanket


#End of hallway objects
#Teddy Bear with a pull string
#treasure chest
#one of the pearls for the hippos


# each_game()
# backstory should be based on your game
# maxiumum of eight choices
# describe room, describe challenge, 
# at least 1 challenge
# 1 treasure teleporter
# rewards 1 blanket piece
# enemy can take away health
# modify player properties with player1.
# do we need to use self?
# we think self.player.health = (self.player.health - damage)
